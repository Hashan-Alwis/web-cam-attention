# %%
import cv2 as cv2
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
img = cv2.imread("RawData\\attention\\WIN_20240220_08_48_57_Pro.jpg")
img = original= cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (720, 1280, 3)

# %%
from mtcnn.mtcnn import MTCNN

# %%
det = MTCNN()

output = det.detect_faces(img)

output
# Out:
# ...
# 1/1 [==============================] - 0s 289ms/step
# [{'box': [536, 110, 208, 288],
#   'confidence': 0.9998201727867126,
#   'keypoints': {'left_eye': (599, 224),
#    'right_eye': (701, 226),
#    'nose': (656, 284),
#    'mouth_left': (606, 334),
#    'mouth_right': (693, 332)}},
#  {'box': [205, 466, 51, 64],
#   'confidence': 0.9951360821723938,
#   'keypoints': {'left_eye': (223, 488),
#    'right_eye': (246, 485),
#    'nose': (240, 500),
#    'mouth_left': (230, 517),
#    'mouth_right': (247, 514)}},
#  {'box': [1167, 457, 26, 32],
#   'confidence': 0.9812864661216736,
#   'keypoints': {'left_eye': (1177, 470),
#    'right_eye': (1186, 468),
#    'nose': (1185, 477),
#    'mouth_left': (1179, 483),
#    'mouth_right': (1186, 482)}}]

# %%
x,y,w,h = output[0]["box"]

# %%
face = cv2.rectangle(img, (x-20,y-20), (x+w+20 , y+h+20), (255, 0, 0), 3)

# %%
plt.imshow(face)

# %%
plt.imshow(face)
